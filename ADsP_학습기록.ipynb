# %% [markdown]
# # ADsP 학습
#
# ## 2024-08-01 21:28 ~ 00:54+1
# - Chapter별 기출문제 풀이(p.17~p.25)
# - 합격마법노트(p.31~p.54)
# - 이산형 확률변수 문제 풀이
#     - E(X) = sum(i) * xi * f(xi) == sum(i) * xi * P(X=xi)
#
#
# ## 2024-08-04 21:21 ~ 00:55+1
# - 1장 데이터 이해(p.61~p.121) / 1장 끝
#
# ## 2024-08-05 22:06 ~ 01:00+1
# - 야근하고 공부하기 힘들다!
# - 2장 데이터 분석 기획(p.125~p.158)
